# %%
from IPython.display import Image
Image('https://pbs.twimg.com/media/B3gcFATCYAEZ5o1.jpg')

# %% [markdown]
# Main talks 20-25 mins each
# -------------------------
#
#  * Eugene Teo - Introduction to Pandas
#  * Alyssa Quek - Face Morpher
#
# Lightning talks 5-10 mins each
# ----------------------------
#
#  * Martin Andrews - TensorFlow
#  * Tsai Liming - Spark Notebook/Jupyter/PySpark
#
# Lucky draw
# ----------
#
# Together with Spark Singapore, we are giving away two free passes to [Strata+Hadoop World Singapore](https://conferences.oreilly.com/strata/big-data-conference-sg-2015/).
#
# Free O'Reilly ebooks
# -------------------
#
#   * Request a free ebook at [http://www.oreilly.com/pub/get/pcpydatasg](http://www.oreilly.com/pub/get/pcpydatasg)
#
# Venue sponsor
# ------------
#
# Thanks to [Holmusk](https://www.holmusk.com/) for the initial venue sponsorship. And thanks to [Red Hat Asia Pacific](http://www.redhat.com/en) for hosting us as we needed a bigger venue!
#
# Food sponsor
# -----------
#
# Thanks to [Adam Drake](http://aadrake.com/) for the pizzas!
#
# Lucky draw and ebook sponsor
# ---------------------------
#
# And finally, thanks to [O'Reilly Media](http://www.oreilly.com/) for sponsoring the ebooks and lucky draw passes!
#
# Looking for speakers and volunteers
# ---------------------------------
#
# Help us make the next PyData meetup even more awesome!
